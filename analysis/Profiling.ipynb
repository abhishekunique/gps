# %%
import pstats

# %%
p = pstats.Stats("/home/kavi/prof-log")
_=p.strip_dirs().sort_stats("cumtime").print_stats(100)
# Out:
# Fri Jun  9 15:42:47 2017    /home/kavi/prof-log
#
#          499808538 function calls (499635892 primitive calls) in 9221.087 seconds
#
#    Ordered by: cumulative time
#    List reduced from 6994 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.013    0.013 9221.293 9221.293 gps_main.py:1(<module>)
#         1    0.000    0.000 9209.256 9209.256 gps_main.py:622(main)
#         1    0.032    0.032 9181.672 9181.672 gps_main.py:176(run_badmm)
#         1    0.179    0.179 7642.786 7642.786 gps_main.py:345(_take_iteration_shared)
#         3  176.846   58.949 4712.564 1570.855 policy_opt_tf.py:403(update_ee)
#     68919    5.820    0.000 4559.150    0.066 session.py:294(run)
#     68919  113.083    0.002 4551.198    0.066 session.py:563(_run)
#     60000    3.325    0.000 4521.835    0.075 tf_utils.py:153(__call__)
#     68919    1.261    0.000 3690.709    0.054 session.py:681(_do_run)
# ...
